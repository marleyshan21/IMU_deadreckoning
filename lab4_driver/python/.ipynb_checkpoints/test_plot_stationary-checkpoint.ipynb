# %%
import bagpy
from bagpy import bagreader
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
b = bagreader("/home/marley/catkin_ws/src/gps_driver/bag_files/stationary_data/2022-09-21-16-43-54.bag")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 b = bagreader("/home/marley/catkin_ws/src/gps_driver/bag_files/2022-09-21-16-43-54.bag")
#
# File ~/.local/lib/python3.8/site-packages/bagpy/bagreader.py:202, in bagreader.__init__(self, bagfile, verbose, tmp)
#     199     self.filename = bagfile
#     200     self.dir = './'
# --> 202 self.reader = rosbag.Bag(self.bagfile)
#     204 info = self.reader.get_type_and_topic_info()
#     205 self.topic_tuple = info.topics.values()
#
# File /opt/ros/noetic/lib/python3/dist-packages/rosbag/bag.py:467, in Bag.__init__(self, f, mode, compression, chunk_threshold, allow_unindexed, options, skip_index)
#     463 self._curr_compression = Compression.NONE
#     465 self._encryptor = _ROSBagNoEncryptor()
# --> 467 self._open(f, mode, allow_unindexed)
#     469 self._output_file = self._file
#
# ...

# %%
b.topic_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 b.topic_table
#
# NameError: name 'b' is not defined

# %%
df_gps = pd.read_csv("/home/marley/catkin_ws/src/gps_driver/bag_files/stationary_data/2022-09-21-16-43-54/gps_mean_corrected.csv")

# %%
df_gps
# Out:
#             Time  Header.seq  Header.stamp.secs  Header.stamp.nsecs  \
# 0     1663793035           0              74635                   0
# 1     1663793036           0              74636                   0
# 2     1663793037           0              74637                   0
# 3     1663793038           0              74638                   0
# 4     1663793039           0              74639                   0
# ...          ...         ...                ...                 ...
# 1415  1663794450           0              76050                   0
# 1416  1663794451           0              76051                   0
# 1417  1663794452           0              76052                   0
# 1418  1663794453           0              76053                   0
# 1419  1663794454           0              76054                   0
#
#      Header.frame_id   Latitude  Longitude  Altitude  UTM_easting  \
# 0         GPS1_Frame  42.337297 -71.090128      -5.3  327814.0717
# ...

# %%
fig, ax = bagpy.create_fig(1)
ax[0].scatter(x='Header.stamp.secs', y='UTM_northing_corrected', data=df_gps)
plt.show()

# %%
fig, ax = bagpy.create_fig(1)
ax[0].scatter(x='Header.stamp.secs', y='UTM_easting_corrected', data=df_gps)
plt.show()

# %%
fig, ax = bagpy.create_fig(1)
ax[0].scatter(x='UTM_easting_corrected', y='UTM_northing_corrected', data=df_gps)
plt.show()

# %%
bagpy.animate_timeseries(df_gps['Time'], df_gps['easting'], title='Velocity Timeseries Plot')
